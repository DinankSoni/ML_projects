# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('./datasets/train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# Get the names of columns with null values
null_columns = df.columns[df.isnull().any()]
# Create a new DataFrame with only the columns containing null values
df[null_columns].isnull().sum()
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# we remove column those have null value > 500

# %%
df.drop(columns=['Alley','FireplaceQu','PoolQC','Fence','MiscFeature'], inplace=True)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Get the names of columns with null values
null_columns = df.columns[df.isnull().any()]
# Create a new DataFrame with only the columns containing null values
df[null_columns].isnull().sum()
# Out:
# LotFrontage     259
# MasVnrType        8
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %%
df.drop(columns=['Id'], axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %% [markdown]
# now fill missing values.

# %%
# Fill null values with mean for each column
df_filled = df.fillna(df.mean())

# Display the DataFrame with null values filled by mean
df_filled
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12604\1097104169.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_filled = df.fillna(df.mean())
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# ...

# %%
# Get the names of columns with null values
null_columns = df.columns[df_filled.isna().any()]
# Create a new DataFrame with only the columns containing null values
df_filled[null_columns].isna().sum()
# Out:
# MasVnrType       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['MasVnrType'].value_counts().reset_index()
result.columns = ['MasVnrType', 'Count']
# Print the result
result
# Out:
#   MasVnrType  Count
# 0       None    864
# 1    BrkFace    445
# 2      Stone    128
# 3     BrkCmn     15

# %%
df['MasVnrType'] = df['MasVnrType'].fillna('BrkFace').apply(lambda x: 'BrkFace' if x in 'None' else x)

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['MasVnrType'].value_counts().reset_index()
result.columns = ['MasVnrType', 'Count']
# Print the result
result
# Out:
#   MasVnrType  Count
# 0    BrkFace   1317
# 1      Stone    128
# 2     BrkCmn     15

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtQual'].value_counts().reset_index()
result.columns = ['BsmtQual', 'Count']
# Print the result
result
# Out:
#   BsmtQual  Count
# 0       TA    649
# 1       Gd    618
# 2       Ex    121
# 3       Fa     35

# %%
df['BsmtQual'] = df['BsmtQual'].fillna('TA')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtQual'].value_counts().reset_index()
result.columns = ['BsmtQual', 'Count']
# Print the result
result
# Out:
#   BsmtQual  Count
# 0       TA    686
# 1       Gd    618
# 2       Ex    121
# 3       Fa     35

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtCond'].value_counts().reset_index()
result.columns = ['BsmtCond', 'Count']
# Print the result
result
# Out:
#   BsmtCond  Count
# 0       TA   1311
# 1       Gd     65
# 2       Fa     45
# 3       Po      2

# %%
df['BsmtCond'] = df['BsmtCond'].fillna('TA')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtCond'].value_counts().reset_index()
result.columns = ['BsmtCond', 'Count']
# Print the result
result
# Out:
#   BsmtCond  Count
# 0       TA   1348
# 1       Gd     65
# 2       Fa     45
# 3       Po      2

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtExposure'].value_counts().reset_index()
result.columns = ['BsmtExposure', 'Count']
# Print the result
result
# Out:
#    BsmtExposure  Count
# 0  BsmtExposure    953
# 1            Av    259
# 2            Gd    134
# 3            Mn    114

# %%
df['BsmtExposure'] = df['BsmtExposure'].fillna('Av').apply(lambda x: 'Av' if x in 'No' else x)

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtExposure'].value_counts().reset_index()
result.columns = ['BsmtExposure', 'Count']
# Print the result
result
# Out:
#   BsmtExposure  Count
# 0           Av   1212
# 1           Gd    134
# 2           Mn    114

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtFinType1'].value_counts().reset_index()
result.columns = ['BsmtFinType1', 'Count']
# Print the result
result
# Out:
#   BsmtFinType1  Count
# 0          Unf    430
# 1          GLQ    418
# 2          ALQ    220
# 3          BLQ    148
# 4          Rec    133
# 5          LwQ     74

# %%
df['BsmtFinType1'] = df['BsmtFinType1'].fillna('Unf')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtFinType1'].value_counts().reset_index()
result.columns = ['BsmtFinType1', 'Count']
# Print the result
result
# Out:
#   BsmtFinType1  Count
# 0          Unf    467
# 1          GLQ    418
# 2          ALQ    220
# 3          BLQ    148
# 4          Rec    133
# 5          LwQ     74

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtFinType2'].value_counts().reset_index()
result.columns = ['BsmtFinType2', 'Count']
# Print the result
result
# Out:
#   BsmtFinType2  Count
# 0          Unf   1294
# 1          Rec     54
# 2          LwQ     46
# 3          BLQ     33
# 4          ALQ     19
# 5          GLQ     14

# %%
df['BsmtFinType2'] = df['BsmtFinType2'].fillna('Unf')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['BsmtFinType2'].value_counts().reset_index()
result.columns = ['BsmtFinType2', 'Count']
# Print the result
result
# Out:
#   BsmtFinType2  Count
# 0          Unf   1294
# 1          Rec     54
# 2          LwQ     46
# 3          BLQ     33
# 4          ALQ     19
# 5          GLQ     14

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['Electrical'].value_counts().reset_index()
result.columns = ['Electrical', 'Count']
# Print the result
result
# Out:
#   Electrical  Count
# 0      SBrkr   1334
# 1      FuseA     94
# 2      FuseF     27
# 3      FuseP      3
# 4        Mix      1

# %%
df['Electrical'] = df['Electrical'].fillna('SBrkr')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['Electrical'].value_counts().reset_index()
result.columns = ['Electrical', 'Count']
# Print the result
result
# Out:
#   Electrical  Count
# 0      SBrkr   1335
# 1      FuseA     94
# 2      FuseF     27
# 3      FuseP      3
# 4        Mix      1

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageType'].value_counts().reset_index()
result.columns = ['GarageType', 'Count']
# Print the result
result
# Out:
#   GarageType  Count
# 0     Attchd    870
# 1     Detchd    387
# 2    BuiltIn     88
# 3    Basment     19
# 4    CarPort      9
# 5     2Types      6

# %%
df['GarageType'] = df['GarageType'].fillna('Attchd')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageType'].value_counts().reset_index()
result.columns = ['GarageType', 'Count']
# Print the result
result
# Out:
#   GarageType  Count
# 0     Attchd    951
# 1     Detchd    387
# 2    BuiltIn     88
# 3    Basment     19
# 4    CarPort      9
# 5     2Types      6

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageFinish'].value_counts().reset_index()
result.columns = ['GarageFinish', 'Count']
# Print the result
result
# Out:
#   GarageFinish  Count
# 0          Unf    605
# 1          RFn    422
# 2          Fin    352

# %%
df['GarageFinish'] = df['GarageFinish'].fillna('Unf')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageFinish'].value_counts().reset_index()
result.columns = ['GarageFinish', 'Count']
# Print the result
result
# Out:
#   GarageFinish  Count
# 0          Unf    686
# 1          RFn    422
# 2          Fin    352

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageQual'].value_counts().reset_index()
result.columns = ['GarageQual', 'Count']
# Print the result
result
# Out:
#   GarageQual  Count
# 0         TA   1311
# 1         Fa     48
# 2         Gd     14
# 3         Ex      3
# 4         Po      3

# %%
df['GarageQual'] = df['GarageQual'].fillna('TA')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageQual'].value_counts().reset_index()
result.columns = ['GarageQual', 'Count']
# Print the result
result
# Out:
#   GarageQual  Count
# 0         TA   1392
# 1         Fa     48
# 2         Gd     14
# 3         Ex      3
# 4         Po      3

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageCond'].value_counts().reset_index()
result.columns = ['GarageCond', 'Count']
# Print the result
result
# Out:
#   GarageCond  Count
# 0         TA   1326
# 1         Fa     35
# 2         Gd      9
# 3         Po      7
# 4         Ex      2

# %%
df['GarageCond'] = df['GarageCond'].fillna('TA')

# %%
# Group the DataFrame by 'MasVnrType' and calculate the sum
result = df['GarageCond'].value_counts().reset_index()
result.columns = ['GarageCond', 'Count']
# Print the result
result
# Out:
#   GarageCond  Count
# 0         TA   1407
# 1         Fa     35
# 2         Gd      9
# 3         Po      7
# 4         Ex      2

# %%
# Get the names of columns with null values
null_columns = df.columns[df_filled.isna().any()]
# Create a new DataFrame with only the columns containing null values
df_filled[null_columns].isna().sum()
# Out:
# MasVnrType       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64

# %%
# List of specific columns for which you want to find unique values
specific_columns = ['MasVnrType', 'BsmtQual', 'BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','GarageType','GarageFinish','GarageQual','GarageCond']  

# Initialize a dictionary to store unique values for each specific column
unique_values_dict = {}

# Iterate through the specific columns and find unique values
for column in specific_columns:
    unique_values = df[column].unique()
    unique_values_dict[column] = unique_values

# Print unique values for each specific column
for column, unique_values in unique_values_dict.items():
    print(f"Unique values for {column}:")
    print(unique_values)
# Out:
# Unique values for MasVnrType:
# ['BrkFace' 'Stone' 'BrkCmn']
# Unique values for BsmtQual:
# ['Gd' 'TA' 'Ex' 'Fa']
# Unique values for BsmtCond:
# ['TA' 'Gd' 'Fa' 'Po']
# Unique values for BsmtExposure:
# ['Av' 'Gd' 'Mn']
# Unique values for BsmtFinType1:
# ['GLQ' 'ALQ' 'Unf' 'Rec' 'BLQ' 'LwQ']
# Unique values for BsmtFinType2:
# ['Unf' 'BLQ' 'ALQ' 'Rec' 'LwQ' 'GLQ']
# Unique values for Electrical:
# ['SBrkr' 'FuseF' 'FuseA' 'FuseP' 'Mix']
# Unique values for GarageType:
# ['Attchd' 'Detchd' 'BuiltIn' 'CarPort' 'Basment' '2Types']
# Unique values for GarageFinish:
# ['RFn' 'Unf' 'Fin']
# Unique values for GarageQual:
# ['TA' 'Fa' 'Gd' 'Ex' 'Po']
# Unique values for GarageCond:
# ['TA' 'Fa' 'Gd' 'Po' 'Ex']

# %%
# List of columns and their default values for filling
columns_to_fill = {
    'MasVnrType': 'BrkFace',
    'BsmtQual': 'TA',
    'BsmtCond': 'TA',
    'BsmtExposure': 'Av',
    'BsmtFinType1': 'Unf',
    'BsmtFinType2': 'Unf',
    'Electrical': 'SBrkr',
    'GarageType': 'Attchd',
    'GarageFinish': 'Unf',
    'GarageQual': 'TA',
    'GarageCond': 'TA'
}

# Loop through the specified columns and fill null values based on unique values
for column, default_value in columns_to_fill.items():
    unique_values = df[column].unique()
    
    # Check if 'None' or 'No' is in unique values, and fill accordingly
    if 'None' in unique_values or 'No' in unique_values:
        df[column] = df[column].fillna(default_value).apply(lambda x: default_value if x in ['None', 'No'] else x)
    else:
        df[column].fillna(default_value, inplace=True)

# %%
# Get the names of columns with null values
null_columns = df.columns[df_filled.isna().any()]
# Create a new DataFrame with only the columns containing null values
df_filled[null_columns].isna().sum()
# Out:
# MasVnrType       8
# BsmtQual        37
# BsmtCond        37
# BsmtExposure    38
# BsmtFinType1    37
# BsmtFinType2    38
# Electrical       1
# GarageType      81
# GarageFinish    81
# GarageQual      81
# GarageCond      81
# dtype: int64
